# %% [markdown]
# # Pyplot Tutorial:
# - matplotlib.pyplot is a collection of command style functions that make matplotlib work like MATLAB.
# - Each pyplot function makes some changeto a figure, eg: creates a figure, creates a plotting area in a figure, plots some lines in a plotting area, decorates the plot with labels etc.

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2, 4, 6, 2])
plt.ylabel("Numbers")
plt.xlabel("Indices")
plt.title("My Plot")
plt.show()

# %% [markdown]
# __If you provide a single list or array to the plot() command, matplotlib assumes it is a sequence of y values and automatically generates the x values for you. Since python ranges start with 0, the default x vector has the same length as y but starts with 0. Hence the x data are [0,1,2,3]__

# %% [markdown]
# ### plot x versus y

# %%
plt.plot([1, 2, 3, 4] , [1, 4, 9, 16])
plt.ylabel("squares")
plt.xlabel("Numbers")
plt.grid()
plt.show()

# %% [markdown]
# __For every x,y pair of arguments, there is an optional third argument which is the *format String* that indicates the color and line type of the plot.__

# %%
plt.plot([1,2,3,4],[1, 4, 9, 16], 'ro')
plt.grid()

plt.show()

# %% [markdown]
# __If matplotlib were limited to working with lists, it would be Fairly useless for numeric processing. Generally, you will use *Numpy Arrays*. Infact, all sequences are converted to numpy arrays internally.__

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t = np.arange(0., 5., 0.2)

#Blue dashes, Red Squares and Green triangles

plt.plot(t, t**2, 'b--', label = '^2')
plt.plot(t, t**2.2, 'rs', label = '^2.2')
plt.plot(t, t**2.4, 'g^',label = '^2.4' )
plt.grid()

plt.legend()  #Add Legend Based on Line Labels
plt.show()

# %% [markdown]
# # Controlling Line Properties
#
# - Use Keyword Args

# %%
x = [1, 2, 3, 4]
y = [1, 4, 9, 16]

plt.plot(x, y, linewidth = 5.0)

plt.show()

# %% [markdown]
# ### Use the setp()

# %%
x1 = [1, 2, 3, 4]
y1 = [1, 4, 9, 16]
x2 = [1, 2, 3, 4]
y2 = [2, 4, 6, 8]

lines = plt.plot(x1, y1, x2, y2)

#Use Keyword args
plt.setp(lines[0], color = 'r' , linewidth = 2.0)

#or MATLAB style string value pairs
plt.setp(lines[1], 'color' , 'g', linewidth = 2.0)

plt.grid()

# %% [markdown]
# # Working with Multiple Figures and Axes

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0.0, 5.0, 0.1)
t2 = np.arange(0.0, 5.0, 0.02)

plt.figure(1)

# The subplot() command specifies numrows, numcols,
# Fignum where fignum ranges from 1 to numrows*numcols.

plt.subplot(211)
plt.grid()
plt.plot(t1, f(t1), 'b-')

plt.subplot(212)
plt.grid()
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()

# %%
plt.figure(1)             #the first figure
plt.subplot(211)          #the first subplot in the first figure
plt.plot([1, 2, 3])       
plt.subplot(212)          #the second subplot in the first figure
plt.plot([4, 5, 6])

plt.figure(2)             #second figure
plt.plot([4, 5, 6])       #creates a subplot(111) by default

plt.figure(1)             #Figure 1 current; subplot(212) still current
plt.subplot(211)          #make subplot(211) in figure 1 current
plt.title("Easy as 1, 2, 3")  #Subplot 211 title
plt.show()

# %% [markdown]
# ### Let's Practice

# %%
t = np.arange(1,10,1)
t1 = np.arange(1.0 , 10.0, 1.0)
t2 = np.arange(1.0, 20.0, 2.0)

plt.figure(1)
plt.subplot(121)
plt.plot(np.sin(t1), 'b-', label="sin(t1)")
plt.legend()
plt.grid()

plt.subplot(122)
plt.plot(np.cos(t1), 'r--', label="cos(t1)")
plt.legend()
plt.grid()

plt.figure(2)
plt.plot(t**2, 'g^', label='t')
plt.legend()
plt.grid()

plt.figure(3)
plt.subplot(121)
plt.plot(np.sin(t2), 'b-', label="sin(t2)")
plt.legend()
plt.grid()

plt.subplot(122)
plt.plot(np.cos(t2), 'r--', label="cos(t2)")
plt.legend()
plt.grid()

plt.show()
